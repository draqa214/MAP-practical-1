# %%
pip install pygame
# Out:
# ...
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB 1.3 MB/s eta 0:00:09
#    ---------------------------------------- 0.0/10.8 MB 1.3 MB/s eta 0:00:09
#    ---------------------------------------- 0.0/10.8 MB 217.9 kB/s eta 0:00:50
#    ---------------------------------------- 0.1/10.8 MB 357.2 kB/s eta 0:00:30
#    ---------------------------------------- 0.1/10.8 MB 435.7 kB/s eta 0:00:25
#    ---------------------------------------- 0.1/10.8 MB 364.4 kB/s eta 0:00:30
#     --------------------------------------- 0.2/10.8 MB 437.1 kB/s eta 0:00:25
#     --------------------------------------- 0.2/10.8 MB 597.3 kB/s eta 0:00:18
#     --------------------------------------- 0.2/10.8 MB 597.3 kB/s eta 0:00:18
#     --------------------------------------- 0.3/10.8 MB 561.1 kB/s eta 0:00:19
# ...

# %%
import pygame
import sys

# Initialize Pygame
pygame.init()

# Set up display
width, height = 800, 600
screen = pygame.display.set_mode((width, height))
pygame.display.set_caption("2D Game - Draw Track and Generate Car")

# Colors
white = (255, 255, 255)
black = (0, 0, 0)

# Game variables
drawing = False
clock = pygame.time.Clock()

# Car
car_img = pygame.Surface((30, 15))
car_img.fill(white)
car_rect = car_img.get_rect(center=(width // 2, height // 2))

# Main game loop
while True:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()

        elif event.type == pygame.MOUSEBUTTONDOWN:
            drawing = True

        elif event.type == pygame.MOUSEMOTION:
            if drawing:
                pygame.draw.circle(screen, white, event.pos, 5)

        elif event.type == pygame.MOUSEBUTTONUP:
            drawing = False

    keys = pygame.key.get_pressed()
    if keys[pygame.K_UP]:
        car_rect.y -= 5
    if keys[pygame.K_DOWN]:
        car_rect.y += 5
    if keys[pygame.K_LEFT]:
        car_rect.x -= 5
    if keys[pygame.K_RIGHT]:
        car_rect.x += 5

    # Update display
    screen.fill(black)
    screen.blit(car_img, car_rect)
    pygame.display.flip()

    # Cap the frame rate
    clock.tick(60)
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.10.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\VIVEK\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:3534: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import pygame
import sys

# Initialize Pygame
pygame.init()

# Set up display
width, height = 800, 600
screen = pygame.display.set_mode((width, height))
pygame.display.set_caption("2D Game - Draw Track and Generate Car")

# Colors
white = (255, 255, 255)
black = (0, 0, 0)
gray = (128, 128, 128)

# Game variables
drawing = False
track_points = []

# Main game loop
while True:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()

        elif event.type == pygame.MOUSEBUTTONDOWN:
            if not track_points:  # Set starting point
                track_points.append(event.pos)
                pygame.draw.circle(screen, black, event.pos, 5)
            else:  # Draw track
                drawing = True

        elif event.type == pygame.MOUSEMOTION:
            if drawing:
                track_points.append(event.pos)
                pygame.draw.lines(screen, gray, False, track_points, 5)

        elif event.type == pygame.MOUSEBUTTONUP:
            drawing = False

    # Update display
    pygame.display.flip()
    screen.fill(white)

    # Cap the frame rate
    pygame.time.Clock().tick(60)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
import pygame
import sys

# Initialize Pygame
pygame.init()

# Set up display
width, height = 800, 600
screen = pygame.display.set_mode((width, height))
pygame.display.set_caption("2D Game - Draw Track and Generate Car")

# Colors
white = (255, 255, 255)
black = (0, 0, 0)
gray = (128, 128, 128)

# Game variables
drawing = False
track_points = []

# Main game loop
while True:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()

        elif event.type == pygame.MOUSEBUTTONDOWN:
            if not track_points:  # Set starting point
                track_points.append(event.pos)
                pygame.draw.circle(screen, black, event.pos, 5)
            else:  # Draw track
                drawing = True

        elif event.type == pygame.MOUSEMOTION:
            if drawing:
                track_points.append(event.pos)

        elif event.type == pygame.MOUSEBUTTONUP:
            drawing = False

    # Update display
    screen.fill(white)

    # Draw the track
    if len(track_points) > 1:
        pygame.draw.lines(screen, gray, False, track_points, 10)

    # Cap the frame rate
    pygame.display.flip()
    pygame.time.Clock().tick(60)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
import pygame
import sys

# Initialize Pygame
pygame.init()

# Set up display
width, height = 800, 600
screen = pygame.display.set_mode((width, height))
pygame.display.set_caption("2D Game - Draw Track and Generate Car")

# Colors
white = (255, 255, 255)
black = (0, 0, 0)
gray = (128, 128, 128)
green = (0, 255, 0)

# Game variables
drawing = False
track_points = []

# Car variables
car_image = pygame.Surface((30, 15))
car_image.fill(black)
car_rect = car_image.get_rect(center=(width // 2, height // 2))

# Main game loop
while True:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()

        elif event.type == pygame.MOUSEBUTTONDOWN:
            if not track_points:  # Set starting point
                start_point = event.pos
                pygame.draw.rect(screen, green, (start_point[0] - 10, start_point[1] - 10, 20, 20))
                pygame.draw.rect(screen, black, (start_point[0] - 5, start_point[1] - 5, 10, 10))
            else:  # Draw track
                drawing = True

        elif event.type == pygame.MOUSEMOTION:
            if drawing:
                track_points.append(event.pos)

        elif event.type == pygame.MOUSEBUTTONUP:
            drawing = False

    # Update display
    screen.fill(white)

    # Draw the track
    if len(track_points) > 1:
        pygame.draw.lines(screen, gray, False, track_points, 10)

    # Draw the car
    screen.blit(car_image, car_rect)

    # Cap the frame rate
    pygame.display.flip()
    pygame.time.Clock().tick(60)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
import pygame
import sys

# Initialize Pygame
pygame.init()

# Set up display
width, height = 800, 600
screen = pygame.display.set_mode((width, height))
pygame.display.set_caption("2D Game - Draw Track and Generate Car")

# Colors
white = (255, 255, 255)
black = (0, 0, 0)
gray = (128, 128, 128)
green = (0, 255, 0)

# Game variables
drawing = False
track_points = []

# Car variables
car_image = pygame.Surface((30, 15))
car_image.fill(black)
car_rect = car_image.get_rect(center=(width // 2, height // 2))

# Main game loop
while True:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()

        elif event.type == pygame.MOUSEBUTTONDOWN:
            if not drawing:
                start_point = event.pos
                pygame.draw.rect(screen, green, (start_point[0] - 10, start_point[1] - 10, 20, 20))
                pygame.draw.rect(screen, black, (start_point[0] - 5, start_point[1] - 5, 10, 10))
                drawing = True
            else:
                track_points.append(event.pos)

        elif event.type == pygame.MOUSEMOTION:
            if drawing:
                track_points.append(event.pos)

        elif event.type == pygame.MOUSEBUTTONUP:
            drawing = False

    # Update display
    screen.fill(white)

    # Draw the track
    if len(track_points) > 1:
        pygame.draw.lines(screen, gray, False, track_points, 10)

    # Draw the car
    screen.blit(car_image, car_rect)

    # Cap the frame rate
    pygame.display.flip()
    pygame.time.Clock().tick(60)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 62
#      60 # Cap the frame rate
#      61 pygame.display.flip()
# ---> 62 pygame.time.Clock().tick(60)
#
# KeyboardInterrupt:

# %%
import pygame
import sys

# Initialize Pygame
pygame.init()

# Set up display
width, height = 800, 600
screen = pygame.display.set_mode((width, height))
pygame.display.set_caption("2D Game - Draw Track and Generate Car")

# Colors
white = (255, 255, 255)
black = (0, 0, 0)
gray = (128, 128, 128)
green = (0, 255, 0)

# Game variables
drawing = False
track_points = []

# Car variables
car_image = pygame.Surface((30, 15), pygame.SRCALPHA)
pygame.draw.rect(car_image, black, (0, 0, 30, 15), 3)  # Less thick black border
car_rect = car_image.get_rect(center=(width // 2, height // 2))

# Main game loop
while True:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()

        elif event.type == pygame.MOUSEBUTTONDOWN:
            if not drawing:
                start_point = event.pos
                pygame.draw.rect(screen, green, (start_point[0] - 10, start_point[1] - 10, 20, 20), 15)  # Thicker green square
                pygame.draw.rect(screen, black, (start_point[0] - 5, start_point[1] - 5, 10, 10), 3)  # Less thick black square
                drawing = True
            else:
                track_points.append(event.pos)

        elif event.type == pygame.MOUSEMOTION:
            if drawing:
                track_points.append(event.pos)

        elif event.type == pygame.MOUSEBUTTONUP:
            drawing = False

    # Update display
    screen.fill(white)

    # Draw the track
    if len(track_points) > 1:
        pygame.draw.lines(screen, gray, False, track_points, 20)  # Thicker track

    # Draw the car
    screen.blit(car_image, car_rect)

    # Cap the frame rate
    pygame.display.flip()
    pygame.time.Clock().tick(60)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
import pygame
import sys

# Initialize Pygame
pygame.init()

# Set up display
width, height = 800, 600
screen = pygame.display.set_mode((width, height))
pygame.display.set_caption("2D Game - Draw Track and Generate Car")

# Colors
white = (255, 255, 255)
black = (0, 0, 0)
gray = (128, 128, 128)
green = (0, 255, 0)

# Game variables
drawing = False
track_points = []
start_point = None  # Store the starting point for the car

# Car variables
car_image = pygame.Surface((30, 15), pygame.SRCALPHA)
pygame.draw.rect(car_image, black, (0, 0, 30, 15), 3)  # Less thick black border
car_rect = car_image.get_rect(center=(width // 2, height // 2))

# Main game loop
while True:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()

        elif event.type == pygame.MOUSEBUTTONDOWN:
            if not drawing:
                if not track_points:
                    start_point = event.pos
                    drawing = True
                else:
                    drawing = False
                    pygame.draw.lines(screen, gray, False, track_points, 20)  # Thicker track
                    pygame.draw.line(screen, black, track_points[-1], start_point, 3)  # Starting line
                continue

            track_points.append(event.pos)

        elif event.type == pygame.MOUSEMOTION:
            if drawing:
                track_points.append(event.pos)

    # Update display
    screen.fill(white)

    # Draw the track
    if len(track_points) > 1:
        pygame.draw.lines(screen, gray, False, track_points, 20)  # Thicker track

    # Draw the car
    if start_point:
        car_rect.center = start_point
        screen.blit(car_image, car_rect)

    # Cap the frame rate
    pygame.display.flip()
    pygame.time.Clock().tick(60)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
import pygame
import sys

# Initialize Pygame
pygame.init()

# Set up display
width, height = 800, 600
screen = pygame.display.set_mode((width, height))
pygame.display.set_caption("2D Game - Draw Track and Generate Car")

# Colors
white = (255, 255, 255)
black = (0, 0, 0)
gray = (128, 128, 128)
green = (0, 255, 0)

# Game variables
drawing = False
track_points = []
start_point = None  # Store the starting point for the car
track_finished = False  # Track completion flag

# Car variables
car_image = pygame.Surface((30, 15), pygame.SRCALPHA)
pygame.draw.rect(car_image, black, (0, 0, 30, 15), 3)  # Less thick black border
car_rect = car_image.get_rect(center=(width // 2, height // 2))

# Main game loop
while True:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()

        elif event.type == pygame.MOUSEBUTTONDOWN:
            if not drawing and not track_finished:
                if not track_points:
                    start_point = event.pos
                    drawing = True
                else:
                    drawing = False
                    track_finished = True
                    pygame.draw.lines(screen, gray, False, track_points, 20)  # Thicker track
                    pygame.draw.line(screen, black, track_points[-1], start_point, 3)  # Starting line
                continue

            if drawing:
                track_points.append(event.pos)

    # Update display
    screen.fill(white)

    # Draw the track
    if len(track_points) > 1 and not track_finished:
        pygame.draw.lines(screen, gray, False, track_points, 20)  # Thicker track

    # Draw the car
    if start_point:
        car_rect.center = start_point
        screen.blit(car_image, car_rect)

    # Cap the frame rate
    pygame.display.flip()
    pygame.time.Clock().tick(60)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
import pygame
import sys

# Initialize Pygame
pygame.init()

# Set up display
width, height = 800, 600
screen = pygame.display.set_mode((width, height))
pygame.display.set_caption("2D Game - Draw Track and Generate Car")

# Colors
white = (255, 255, 255)
black = (0, 0, 0)
gray = (128, 128, 128)
green = (0, 255, 0)

# Game variables
drawing = False
track_points = []
start_point = None  # Store the starting point for the car
track_finished = False  # Track completion flag

# Car variables
car_image = pygame.Surface((30, 15), pygame.SRCALPHA)
pygame.draw.rect(car_image, black, (0, 0, 30, 15), 3)  # Less thick black border
car_rect = car_image.get_rect(center=(width // 2, height // 2))

# Main game loop
while True:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()

        elif event.type == pygame.MOUSEBUTTONDOWN:
            if not track_finished:
                if not drawing:
                    if not track_points:
                        start_point = event.pos
                    drawing = True
                else:
                    drawing = False
                    track_finished = True
                    pygame.draw.lines(screen, gray, False, track_points, 20)  # Thicker track
                    pygame.draw.line(screen, black, track_points[-1], start_point, 3)  # Starting line
            continue

        if drawing:
            track_points.append(event.pos)

    # Update display
    screen.fill(white)

    # Draw the track
    if len(track_points) > 1 and not track_finished:
        pygame.draw.lines(screen, gray, False, track_points, 20)  # Thicker track

    # Draw the car
    if start_point:
        car_rect.center = start_point
        screen.blit(car_image, car_rect)

    # Cap the frame rate
    pygame.display.flip()
    pygame.time.Clock().tick(60)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
import pygame
import sys

# Initialize Pygame
pygame.init()

# Set up display
width, height = 800, 600
screen = pygame.display.set_mode((width, height))
pygame.display.set_caption("2D Game - Draw Track and Generate Car")

# Colors
white = (255, 255, 255)
black = (0, 0, 0)

# Function to draw a line with variable thickness
def draw_thick_line(surface, color, start, end, thickness):
    delta_x = end[0] - start[0]
    delta_y = end[1] - start[1]
    distance = max(abs(delta_x), abs(delta_y))
    for i in range(distance):
        x = int(start[0] + float(i) / distance * delta_x)
        y = int(start[1] + float(i) / distance * delta_y)
        pygame.draw.circle(surface, color, (x, y), thickness // 2)

# Game variables
drawing = False
track_points = []
start_point = None  # Store the starting point for the car
track_finished = False  # Track completion flag

# Car variables
car_thickness = 20  # Initial thickness of the car
track_thickness = 75  # Initial thickness of the track
car_image = pygame.Surface((30, 15), pygame.SRCALPHA)
pygame.draw.rect(car_image, black, (0, 0, 30, 15), car_thickness)  # Set car thickness
car_rect = car_image.get_rect(center=(width // 2, height // 2))

# Main game loop
while True:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()

        elif event.type == pygame.MOUSEBUTTONDOWN:
            if not track_finished:
                if not drawing:
                    if not track_points:
                        start_point = event.pos
                    drawing = True
                else:
                    drawing = False
                    track_finished = True
                    draw_thick_line(screen, black, track_points[-1], start_point, track_thickness)  # Draw starting line
            continue

        if drawing:
            track_points.append(event.pos)

    # Update display
    screen.fill(white)

    # Draw the track
    if len(track_points) > 1 and not track_finished:
        draw_thick_line(screen, black, track_points[0], track_points[-1], track_thickness)  # Draw track

    # Draw the car
    if start_point:
        car_rect.center = start_point
        screen.blit(car_image, car_rect)

    # Cap the frame rate
    pygame.display.flip()
    pygame.time.Clock().tick(60)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 59
#      56         continue
#      58     if drawing:
# ---> 59         track_points.append(event.pos)
#      61 # Update display
#      62 screen.fill(white)
#
# AttributeError: 'pygame.event.Event' object has no attribute 'pos'
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pygame
import sys

# Initialize Pygame
pygame.init()

# Set up display
width, height = 800, 600
screen = pygame.display.set_mode((width, height))
pygame.display.set_caption("2D Game - Draw Track and Generate Car")

# Colors
white = (255, 255, 255)
black = (0, 0, 0)

# Function to draw a line with variable thickness
def draw_thick_line(surface, color, start, end, thickness):
    delta_x = end[0] - start[0]
    delta_y = end[1] - start[1]
    distance = max(abs(delta_x), abs(delta_y))
    for i in range(distance):
        x = int(start[0] + float(i) / distance * delta_x)
        y = int(start[1] + float(i) / distance * delta_y)
        pygame.draw.circle(surface, color, (x, y), thickness // 2)

# Game variables
drawing = False
track_points = []
start_point = None  # Store the starting point for the car
track_finished = False  # Track completion flag

# Car variables
car_thickness = 50  # Initial thickness of the car
track_thickness = 200  # Initial thickness of the track
car_image = pygame.Surface((30, 15), pygame.SRCALPHA)
pygame.draw.rect(car_image, black, (0, 0, 30, 15), car_thickness)  # Set car thickness
car_rect = car_image.get_rect(center=(width // 2, height // 2))

# Main game loop
while True:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()

        elif event.type == pygame.MOUSEBUTTONDOWN:
            if not track_finished:
                if not drawing:
                    if not track_points:
                        start_point = event.pos
                    drawing = True
                else:
                    drawing = False
                    track_finished = True
                    pygame.draw.lines(screen, black, False, track_points + [start_point], track_thickness)  # Draw track

    # Update display
    screen.fill(white)

    # Draw the car
    if start_point:
        car_rect.center = start_point
        screen.blit(car_image, car_rect)

    # Draw the track
    if len(track_points) > 1 and not track_finished:
        draw_thick_line(screen, black, track_points[0], track_points[-1], track_thickness)  # Draw incomplete track

    # Cap the frame rate
    pygame.display.flip()
    pygame.time.Clock().tick(60)
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.10.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\VIVEK\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:3534: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import pygame
import sys

# Initialize Pygame
pygame.init()

# Set up display
width, height = 800, 600
screen = pygame.display.set_mode((width, height))
pygame.display.set_caption("2D Game - Draw Track and Generate Car")

# Colors
white = (255, 255, 255)
black = (0, 0, 0)

# Function to draw a line with variable thickness
def draw_thick_line(surface, color, start, end, thickness):
    delta_x = end[0] - start[0]
    delta_y = end[1] - start[1]
    distance = max(abs(delta_x), abs(delta_y))
    for i in range(distance):
        x = int(start[0] + float(i) / distance * delta_x)
        y = int(start[1] + float(i) / distance * delta_y)
        pygame.draw.circle(surface, color, (x, y), thickness // 2)

# Game variables
drawing = False
track_points = []
start_point = None  # Store the starting point for the car
track_finished = False  # Track completion flag

# Car variables
car_thickness = 20  # Initial thickness of the car
track_thickness = 75  # Initial thickness of the track
car_image = pygame.Surface((30, 15), pygame.SRCALPHA)
pygame.draw.rect(car_image, black, (0, 0, 30, 15), car_thickness)  # Set car thickness
car_rect = car_image.get_rect(center=(width // 2, height // 2))

# Main game loop
clock = pygame.time.Clock()

while True:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()

        elif event.type == pygame.MOUSEBUTTONDOWN:
            if not track_finished:
                if not drawing:
                    if not track_points:
                        start_point = event.pos
                    drawing = True
                else:
                    drawing = False
                    track_finished = True
                    draw_thick_line(screen, black, track_points[-1], start_point, track_thickness)  # Draw starting line
            continue

        if drawing:
            track_points.append(event.pos)

    # Update display
    screen.fill(white)

    # Draw the track
    if len(track_points) > 1 and not track_finished:
        draw_thick_line(screen, black, track_points[0], track_points[-1], track_thickness)  # Draw track

    # Draw the car
    if start_point:
        car_rect.center = start_point
        screen.blit(car_image, car_rect)

    # Cap the frame rate
    pygame.display.flip()
    clock.tick(60)
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.10.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\VIVEK\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:3534: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import pygame
import sys

# Initialize Pygame
pygame.init()

# Set up display
width, height = 800, 600
screen = pygame.display.set_mode((width, height))
pygame.display.set_caption("2D Game - Draw Track and Generate Car")

# Colors
white = (255, 255, 255)
black = (0, 0, 0)

# Function to draw a line with variable thickness
def draw_thick_line(surface, color, start, end, thickness):
    delta_x = end[0] - start[0]
    delta_y = end[1] - start[1]
    distance = max(abs(delta_x), abs(delta_y))
    for i in range(distance):
        x = int(start[0] + float(i) / distance * delta_x)
        y = int(start[1] + float(i) / distance * delta_y)
        pygame.draw.circle(surface, color, (x, y), thickness // 2)

# Game variables
drawing = False
track_points = []
start_point = None  # Store the starting point for the car
track_finished = False  # Track completion flag

# Car variables
car_thickness = 20  # Initial thickness of the car
track_thickness = 75  # Initial thickness of the track
car_image = pygame.Surface((30, 15), pygame.SRCALPHA)
pygame.draw.rect(car_image, black, (0, 0, 30, 15), car_thickness)  # Set car thickness
car_rect = car_image.get_rect(center=(width // 2, height // 2))

# Main game loop
clock = pygame.time.Clock()

while True:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()

        elif event.type == pygame.MOUSEBUTTONDOWN:
            if not track_finished:
                if not drawing:
                    if not track_points:
                        start_point = event.pos
                    drawing = True
                else:
                    drawing = False
                    track_finished = True
                    draw_thick_line(screen, black, track_points[-1], start_point, track_thickness)  # Draw starting line
            continue

        elif event.type == pygame.MOUSEMOTION:  # Added this condition for drawing
            if drawing:
                track_points.append(event.pos)

    # Update display
    screen.fill(white)

    # Draw the track
    if len(track_points) > 1 and not track_finished:
        draw_thick_line(screen, black, track_points[0], track_points[-1], track_thickness)  # Draw track

    # Draw the car
    if start_point:
        car_rect.center = start_point
        screen.blit(car_image, car_rect)

    # Cap the frame rate
    pygame.display.flip()
    clock.tick(60)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 57
#      55             drawing = False
#      56             track_finished = True
# ---> 57             draw_thick_line(screen, black, track_points[-1], start_point, track_thickness)  # Draw starting line
#      58     continue
#      60 elif event.type == pygame.MOUSEMOTION:  # Added this condition for drawing
#
# IndexError: list index out of range
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
